# %%
import os
from time import sleep

import pandas as pd
import phoenix as px
from datasets import Dataset
from dotenv import load_dotenv
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains.retrieval import create_retrieval_chain
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import AzureChatOpenAI, AzureOpenAIEmbeddings
from phoenix.session.evaluation import get_qa_with_reference
from phoenix.trace import SpanEvaluations, using_project
from phoenix.trace.langchain import LangChainInstrumentor
from ragas import evaluate
from ragas.metrics import (
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness, answer_correctness,
)

# %%
# load .env file
load_dotenv()

# get azure credentials from .env file
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
api_version = os.getenv("AZURE_OPENAI_VERSION")
deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT")
embedding_deployment_name = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT")
api_key = os.getenv("AZURE_OPENAI_API_KEY")
temperature = os.getenv("TEMPERATURE")

# %%
def build_chain(embeddings_model, model):
    # load vectorstore
    vectorstore = Chroma(embedding_function=embeddings_model, persist_directory="./chroma_db")

    # initialize a retriever from the vectorstore
    retriever = vectorstore.as_retriever()

    # crate a system prompt that tells the LLM to answer questions based on the given context
    # and use a variable that represents the context
    system_prompt = (
        "You are an assistant for question-answering tasks. "
        "Use the following pieces of retrieved context to answer "
        "the question. If you don't know the answer, say that you "
        "don't know. Use three sentences maximum and keep the "
        "answer concise."
        "\n\n"
        "{context}"
    )

    # create a prompt template with the system prompt
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system_prompt),
            ("human", "{input}"),
        ]
    )

    # create a helper chain that inserts the retrieved documents into the prompt
    question_answer_chain = create_stuff_documents_chain(model, prompt)

    # create the final RAG chai
    chain = create_retrieval_chain(retriever, question_answer_chain)

    return chain

# %%
def generate_ragas_dataset(chain, test_data_df):
    test_questions = test_data_df["question"].values

    # execute chain and store answers and retrieved context
    responses = [
        chain.invoke({"input": question})
        for question in test_questions
    ]

    contexts = []
    for response in responses:
        page_contents = [doc.page_content for doc in response["context"]]
        contexts.append(page_contents)

    test_data_df["answer"] = [response["answer"] for response in responses]
    test_data_df["contexts"] = contexts
    test_dataset = Dataset.from_pandas(test_data_df)

    return test_dataset

# %%
# initialize the Embedding Model
embeddings = AzureOpenAIEmbeddings(
    api_version=api_version,
    openai_api_type='azure',
    azure_endpoint=azure_endpoint,
    azure_deployment=embedding_deployment_name,
)

# initialize the Azure OpenAI Model
model = AzureChatOpenAI(
    azure_endpoint=azure_endpoint,
    deployment_name=deployment_name,
    api_key=api_key,
    api_version=api_version,
    openai_api_type="azure",
    temperature=0.0,
    streaming=True,
)

# %%
# create a chain
chain = build_chain(embeddings, model)

# %%
# read in the testset as a dataframe
evaluation_data = pd.read_csv(
    "testdata.csv",
    usecols=["question", "ground_truth"],
)

# %%
# start phoenix session and client
session = px.launch_app(use_temp_dir=False)
client = px.Client()

# initialize Langchain auto-instrumentation
LangChainInstrumentor().instrument()
# Out:
# WARNI [phoenix.session.session] Existing running Phoenix instance detected! Shutting it down and starting a new instance...
# WARNI [opentelemetry.instrumentation.instrumentor] Attempting to instrument while already instrumented
# 🌍 To view the Phoenix app in your browser, visit http://localhost:6006/
# 💽 Your data is being persisted to sqlite:///C:\Users\Johanna Heinz\.phoenix/phoenix.db
# 📖 For more information on how to use Phoenix, check out https://docs.arize.com/phoenix

# %%
# create ragas testset in an extra project
with using_project("test"):
    ragas_eval_dataset = generate_ragas_dataset(chain, evaluation_data)

ragas_evals_df = pd.DataFrame(ragas_eval_dataset)

ragas_evals_df
# Out:
#                                             question  \
# 0  Wie bringt die interne Datenakademie der Merck...
# 1  Wie hat die Einführung der Transformer-Archite...
# 2  Wie können Data Scientists realistisches Erwar...
# 3  Wie tragen Data-Governance und MLOps-Techniken...
# 4  Wie wird die Sentimentanalyse mit LLMs im Work...
# 5  Welche 4 Risikogruppen für KI-Systeme erforder...
# 6  Wie verbessert Christian Winkler die UX in NLP...
# 7  How do data availability and explainable AI im...
# 8  How has Kira Engelhardt's finance background a...
# 9  Welche technischen Anforderungen gibt es für T...
#
#                                         ground_truth  \
# 0  Die interne Datenakademie der Merck KGaA bring...
# 1  Nach der Einführung der Transformer-Architektu...
# 2  Data Scientists können realistisches Erwartung...
# 3  Data-Governance und MLOps-Techniken tragen zur...
# 4  Die Sentimentanalyse wird im Workshop mit LLMs...
# 5  Die vier Risikogruppen für KI-Systeme sind ver...
# 6  Christian Winkler konzentriert sich auf die Op...
# 7  The context discusses the impact of data avail...
# 8  Kira Engelhardt's finance background and leade...
# 9  Die technischen Anforderungen für Teilnehmer, ...
#
#                                               answer  \
# 0  Boris Adryan, der Akademische Direktor der int...
# 1  Die Einführung der Transformer-Architektur dur...
# 2  Data Scientists können realistisches Erwartung...
# 3  Die Anwendung von etablierten Data-Governance,...
# 4  Im Workshop wird die Sentimentanalyse mit LLMs...
# 5  Der EU AI Act kategorisiert KI-Systeme in vier...
# 6  Christian Winkler beschäftigt sich als Profess...
# 7  The increasing availability of data and data e...
# 8  The provided context does not provide a direct...
# 9  Teilnehmer sollten einen Laptop mitbringen, de...
#
#                                             contexts
# 0  [Wieviel KI müssen wir unseren Kunden erklären...
# 1  [Eine Einführung in Large Language Models\n\nC...
# 2  [KI Power-Play: Realistisches Erwartungsmanage...
# 3  [Die Engineering-Perspektive auf den EU AI Act...
# 4  [Datenanalyse mit Machine Learning\n\nIn diese...
# 5  [Die Engineering-Perspektive auf den EU AI Act...
# 6  [Schluss mit Prototyp: GPTx und RAG in der Pra...
# 7  [Datenanalysen im Fußball – ein Überblick\n\nS...
# 8  [KI Power-Play: Realistisches Erwartungsmanage...
# 9  [Datenanalyse mit Machine Learning\n\nIn diese...

# %%
# wait a few seconds in case data hasn't become fully available yet
sleep(5)

# collect information about rag spans
spans_dataframe = get_qa_with_reference(client, project_name="test")

spans_dataframe
# Out:
#                                                               input  \
# context.span_id
# ad86cab1546cbb01  Wie bringt die interne Datenakademie der Merck...
# f7708d5ab80afdbf  Wie hat die Einführung der Transformer-Archite...
# 891952c0033111dd  Wie können Data Scientists realistisches Erwar...
# 1ec859b0e0c6be65  Wie tragen Data-Governance und MLOps-Techniken...
# 5cbfb97080b2bf4b  Wie wird die Sentimentanalyse mit LLMs im Work...
# b499be3f11cd7a3f  Welche 4 Risikogruppen für KI-Systeme erforder...
# 5cf6490c107d3236  Wie verbessert Christian Winkler die UX in NLP...
# 37f307177c5ac005  How do data availability and explainable AI im...
# 07d83b31009459a5  How has Kira Engelhardt's finance background a...
# 37cee3b3a2302228  Welche technischen Anforderungen gibt es für T...
# b5277b56bff23d2e  Wie bringt die interne Datenakademie der Merck...
# e487eb2656b5f5b6  Wie hat die Einführung der Transformer-Archite...
# 34724840206810f6  Wie können Data Scientists realistisches Erwar...
# 1c7046cb905d4e37  Wie tragen Data-Governance und MLOps-Techniken...
# f4b800a932dc2779  Wie wird die Sentimentanalyse mit LLMs im Work...
# 70ff1adfbb5a54c9  Welche 4 Risikogruppen für KI-Systeme erforder...
# a1f7dd654fe09860  Wie verbessert Christian Winkler die UX in NLP...
# a2d50c338d0f6458  How do data availability and explainable AI im...
# 9e902be8425297fc  How has Kira Engelhardt's finance background a...
# 3ba4da06e0cbc447  Welche technischen Anforderungen gibt es für T...
# 823f58f7ae7c61a8  Wie bringt die interne Datenakademie der Merck...
# 5fd6f372b905f4fe  Wie hat die Einführung der Transformer-Archite...
# 5239d60555f250d6  Wie können Data Scientists realistisches Erwar...
# 02a868d0d0d1e0a4  Wie tragen Data-Governance und MLOps-Techniken...
# d5ead2524ba010e5  Wie wird die Sentimentanalyse mit LLMs im Work...
# 591497fe8533b390  Welche 4 Risikogruppen für KI-Systeme erforder...
# 2e08710b7bea8cda  Wie verbessert Christian Winkler die UX in NLP...
# 0bdfaffa73c6b7d3  How do data availability and explainable AI im...
# 1c00fc3e0778611e  How has Kira Engelhardt's finance background a...
# 230725292e5e5dee  Welche technischen Anforderungen gibt es für T...
# 0616212db9aab499  Wie bringt die interne Datenakademie der Merck...
# 674a8bf990968e78  Wie hat die Einführung der Transformer-Archite...
# 4a05eed81a3dd6ad  Wie können Data Scientists realistisches Erwar...
# d98c6443a5511461  Wie tragen Data-Governance und MLOps-Techniken...
# 8fd2b0211b28b80a  Wie wird die Sentimentanalyse mit LLMs im Work...
# 22c96dcfc0ff5b1e  Welche 4 Risikogruppen für KI-Systeme erforder...
# 202223b138467df4  Wie verbessert Christian Winkler die UX in NLP...
# a11241785494cb6d  How do data availability and explainable AI im...
# 1a64b51001a51c9a  How has Kira Engelhardt's finance background a...
# d650c08468fc21e6  Welche technischen Anforderungen gibt es für T...
# 0e4615d93a69793f  Wie bringt die interne Datenakademie der Merck...
# 02a10fc00107faf2  Wie hat die Einführung der Transformer-Archite...
# f861e8037aac88d6  Wie können Data Scientists realistisches Erwar...
# 0870ece95279e251  Wie tragen Data-Governance und MLOps-Techniken...
# 14593e4932b2325f  Wie wird die Sentimentanalyse mit LLMs im Work...
# ff510846d8a27dd6  Wie bringt die interne Datenakademie der Merck...
# c593a3ad68233759  Wie hat die Einführung der Transformer-Archite...
# 2955a30b64c9b9f3  Wie können Data Scientists realistisches Erwar...
# 1074a2db6602f47b  Wie tragen Data-Governance und MLOps-Techniken...
# 65ee609a2cfebad2  Wie wird die Sentimentanalyse mit LLMs im Work...
# 56c5d15d9d831f72  Welche 4 Risikogruppen für KI-Systeme erforder...
# 982bc187bbcb1bf4  Wie verbessert Christian Winkler die UX in NLP...
# c8ee500a99a8d878  How do data availability and explainable AI im...
# b7f38d59445627ad  How has Kira Engelhardt's finance background a...
# 543a2314abcadfe9  Welche technischen Anforderungen gibt es für T...
#
#                                                              output  \
# context.span_id
# ad86cab1546cbb01  {"input": "Wie bringt die interne Datenakademi...
# f7708d5ab80afdbf  {"input": "Wie hat die Einführung der Transfor...
# 891952c0033111dd  {"input": "Wie können Data Scientists realisti...
# 1ec859b0e0c6be65  {"input": "Wie tragen Data-Governance und MLOp...
# 5cbfb97080b2bf4b  {"input": "Wie wird die Sentimentanalyse mit L...
# b499be3f11cd7a3f  {"input": "Welche 4 Risikogruppen für KI-Syste...
# 5cf6490c107d3236  {"input": "Wie verbessert Christian Winkler di...
# 37f307177c5ac005  {"input": "How do data availability and explai...
# 07d83b31009459a5  {"input": "How has Kira Engelhardt's finance b...
# 37cee3b3a2302228  {"input": "Welche technischen Anforderungen gi...
# b5277b56bff23d2e  {"input": "Wie bringt die interne Datenakademi...
# e487eb2656b5f5b6  {"input": "Wie hat die Einführung der Transfor...
# 34724840206810f6  {"input": "Wie können Data Scientists realisti...
# 1c7046cb905d4e37  {"input": "Wie tragen Data-Governance und MLOp...
# f4b800a932dc2779  {"input": "Wie wird die Sentimentanalyse mit L...
# 70ff1adfbb5a54c9  {"input": "Welche 4 Risikogruppen für KI-Syste...
# a1f7dd654fe09860  {"input": "Wie verbessert Christian Winkler di...
# a2d50c338d0f6458  {"input": "How do data availability and explai...
# 9e902be8425297fc  {"input": "How has Kira Engelhardt's finance b...
# 3ba4da06e0cbc447  {"input": "Welche technischen Anforderungen gi...
# 823f58f7ae7c61a8  {"input": "Wie bringt die interne Datenakademi...
# 5fd6f372b905f4fe  {"input": "Wie hat die Einführung der Transfor...
# 5239d60555f250d6  {"input": "Wie können Data Scientists realisti...
# 02a868d0d0d1e0a4  {"input": "Wie tragen Data-Governance und MLOp...
# d5ead2524ba010e5  {"input": "Wie wird die Sentimentanalyse mit L...
# 591497fe8533b390  {"input": "Welche 4 Risikogruppen für KI-Syste...
# 2e08710b7bea8cda  {"input": "Wie verbessert Christian Winkler di...
# 0bdfaffa73c6b7d3  {"input": "How do data availability and explai...
# 1c00fc3e0778611e  {"input": "How has Kira Engelhardt's finance b...
# 230725292e5e5dee  {"input": "Welche technischen Anforderungen gi...
# 0616212db9aab499  {"input": "Wie bringt die interne Datenakademi...
# 674a8bf990968e78  {"input": "Wie hat die Einführung der Transfor...
# 4a05eed81a3dd6ad  {"input": "Wie können Data Scientists realisti...
# d98c6443a5511461  {"input": "Wie tragen Data-Governance und MLOp...
# 8fd2b0211b28b80a  {"input": "Wie wird die Sentimentanalyse mit L...
# 22c96dcfc0ff5b1e  {"input": "Welche 4 Risikogruppen für KI-Syste...
# 202223b138467df4  {"input": "Wie verbessert Christian Winkler di...
# a11241785494cb6d  {"input": "How do data availability and explai...
# 1a64b51001a51c9a  {"input": "How has Kira Engelhardt's finance b...
# d650c08468fc21e6  {"input": "Welche technischen Anforderungen gi...
# 0e4615d93a69793f  {"input": "Wie bringt die interne Datenakademi...
# 02a10fc00107faf2  {"input": "Wie hat die Einführung der Transfor...
# f861e8037aac88d6  {"input": "Wie können Data Scientists realisti...
# 0870ece95279e251  {"input": "Wie tragen Data-Governance und MLOp...
# 14593e4932b2325f                                               None
# ff510846d8a27dd6  {"input": "Wie bringt die interne Datenakademi...
# c593a3ad68233759  {"input": "Wie hat die Einführung der Transfor...
# 2955a30b64c9b9f3  {"input": "Wie können Data Scientists realisti...
# 1074a2db6602f47b  {"input": "Wie tragen Data-Governance und MLOp...
# 65ee609a2cfebad2  {"input": "Wie wird die Sentimentanalyse mit L...
# 56c5d15d9d831f72  {"input": "Welche 4 Risikogruppen für KI-Syste...
# 982bc187bbcb1bf4  {"input": "Wie verbessert Christian Winkler di...
# c8ee500a99a8d878  {"input": "How do data availability and explai...
# b7f38d59445627ad  {"input": "How has Kira Engelhardt's finance b...
# 543a2314abcadfe9  {"input": "Welche technischen Anforderungen gi...
#
#                                                           reference
# context.span_id
# ad86cab1546cbb01  Wieviel KI müssen wir unseren Kunden erklären?...
# f7708d5ab80afdbf  Eine Einführung in Large Language Models\n\nCh...
# 891952c0033111dd  KI Power-Play: Realistisches Erwartungsmanagem...
# 1ec859b0e0c6be65  Die Engineering-Perspektive auf den EU AI Act\...
# 5cbfb97080b2bf4b  Datenanalyse mit Machine Learning\n\nIn diesem...
# b499be3f11cd7a3f  Die Engineering-Perspektive auf den EU AI Act\...
# 5cf6490c107d3236  Schluss mit Prototyp: GPTx und RAG in der Prax...
# 37f307177c5ac005  Datenanalysen im Fußball – ein Überblick\n\nSe...
# 07d83b31009459a5  KI Power-Play: Realistisches Erwartungsmanagem...
# 37cee3b3a2302228  Datenanalyse mit Machine Learning\n\nIn diesem...
# b5277b56bff23d2e  Wieviel KI müssen wir unseren Kunden erklären?...
# e487eb2656b5f5b6  Eine Einführung in Large Language Models\n\nCh...
# 34724840206810f6  KI Power-Play: Realistisches Erwartungsmanagem...
# 1c7046cb905d4e37  Die Engineering-Perspektive auf den EU AI Act\...
# f4b800a932dc2779  Datenanalyse mit Machine Learning\n\nIn diesem...
# 70ff1adfbb5a54c9  Die Engineering-Perspektive auf den EU AI Act\...
# a1f7dd654fe09860  Schluss mit Prototyp: GPTx und RAG in der Prax...
# a2d50c338d0f6458  Datenanalysen im Fußball – ein Überblick\n\nSe...
# 9e902be8425297fc  KI Power-Play: Realistisches Erwartungsmanagem...
# 3ba4da06e0cbc447  Datenanalyse mit Machine Learning\n\nIn diesem...
# 823f58f7ae7c61a8  Wieviel KI müssen wir unseren Kunden erklären?...
# 5fd6f372b905f4fe  Eine Einführung in Large Language Models\n\nCh...
# 5239d60555f250d6  KI Power-Play: Realistisches Erwartungsmanagem...
# 02a868d0d0d1e0a4  Die Engineering-Perspektive auf den EU AI Act\...
# d5ead2524ba010e5  Datenanalyse mit Machine Learning\n\nIn diesem...
# 591497fe8533b390  Die Engineering-Perspektive auf den EU AI Act\...
# 2e08710b7bea8cda  Schluss mit Prototyp: GPTx und RAG in der Prax...
# 0bdfaffa73c6b7d3  Datenanalysen im Fußball – ein Überblick\n\nSe...
# 1c00fc3e0778611e  KI Power-Play: Realistisches Erwartungsmanagem...
# 230725292e5e5dee  Datenanalyse mit Machine Learning\n\nIn diesem...
# 0616212db9aab499  Wieviel KI müssen wir unseren Kunden erklären?...
# 674a8bf990968e78  Eine Einführung in Large Language Models\n\nCh...
# 4a05eed81a3dd6ad  KI Power-Play: Realistisches Erwartungsmanagem...
# d98c6443a5511461  Die Engineering-Perspektive auf den EU AI Act\...
# 8fd2b0211b28b80a  Datenanalyse mit Machine Learning\n\nIn diesem...
# 22c96dcfc0ff5b1e  Die Engineering-Perspektive auf den EU AI Act\...
# 202223b138467df4  Schluss mit Prototyp: GPTx und RAG in der Prax...
# a11241785494cb6d  Datenanalysen im Fußball – ein Überblick\n\nSe...
# 1a64b51001a51c9a  KI Power-Play: Realistisches Erwartungsmanagem...
# d650c08468fc21e6  Datenanalyse mit Machine Learning\n\nIn diesem...
# 0e4615d93a69793f  Wieviel KI müssen wir unseren Kunden erklären?...
# 02a10fc00107faf2  Eine Einführung in Large Language Models\n\nCh...
# f861e8037aac88d6  KI Power-Play: Realistisches Erwartungsmanagem...
# 0870ece95279e251  Die Engineering-Perspektive auf den EU AI Act\...
# 14593e4932b2325f  Datenanalyse mit Machine Learning\n\nIn diesem...
# ff510846d8a27dd6  Wieviel KI müssen wir unseren Kunden erklären?...
# c593a3ad68233759  Eine Einführung in Large Language Models\n\nCh...
# 2955a30b64c9b9f3  KI Power-Play: Realistisches Erwartungsmanagem...
# 1074a2db6602f47b  Die Engineering-Perspektive auf den EU AI Act\...
# 65ee609a2cfebad2  Datenanalyse mit Machine Learning\n\nIn diesem...
# 56c5d15d9d831f72  Die Engineering-Perspektive auf den EU AI Act\...
# 982bc187bbcb1bf4  Schluss mit Prototyp: GPTx und RAG in der Prax...
# c8ee500a99a8d878  Datenanalysen im Fußball – ein Überblick\n\nSe...
# b7f38d59445627ad  KI Power-Play: Realistisches Erwartungsmanagem...
# 543a2314abcadfe9  Datenanalyse mit Machine Learning\n\nIn diesem...

# %%
# use extra project to see how ragas works under the hood
with using_project("ragas-evals"):
    # start evaluation
    evaluation_result = evaluate(
        dataset=ragas_eval_dataset,
        metrics=[faithfulness, answer_correctness, context_recall, context_precision],
        llm=model,
        embeddings=embeddings
    )
    
# get evaluation scores
eval_scores_df = pd.DataFrame(evaluation_result.scores)

# get evaluation data
eval_data_df = pd.DataFrame(evaluation_result.dataset)
eval_data_df
# Out:
# Evaluating:   0%|          | 0/40 [00:00<?, ?it/s]
#                                             question  \
# 0  Wie bringt die interne Datenakademie der Merck...
# 1  Wie hat die Einführung der Transformer-Archite...
# 2  Wie können Data Scientists realistisches Erwar...
# 3  Wie tragen Data-Governance und MLOps-Techniken...
# 4  Wie wird die Sentimentanalyse mit LLMs im Work...
# 5  Welche 4 Risikogruppen für KI-Systeme erforder...
# 6  Wie verbessert Christian Winkler die UX in NLP...
# 7  How do data availability and explainable AI im...
# 8  How has Kira Engelhardt's finance background a...
# 9  Welche technischen Anforderungen gibt es für T...
#
#                                         ground_truth  \
# 0  Die interne Datenakademie der Merck KGaA bring...
# 1  Nach der Einführung der Transformer-Architektu...
# 2  Data Scientists können realistisches Erwartung...
# 3  Data-Governance und MLOps-Techniken tragen zur...
# 4  Die Sentimentanalyse wird im Workshop mit LLMs...
# 5  Die vier Risikogruppen für KI-Systeme sind ver...
# 6  Christian Winkler konzentriert sich auf die Op...
# 7  The context discusses the impact of data avail...
# 8  Kira Engelhardt's finance background and leade...
# 9  Die technischen Anforderungen für Teilnehmer, ...
#
#                                               answer  \
# 0  Boris Adryan, der Akademische Direktor der int...
# 1  Die Einführung der Transformer-Architektur dur...
# 2  Data Scientists können realistisches Erwartung...
# 3  Die Anwendung von etablierten Data-Governance,...
# 4  Im Workshop wird die Sentimentanalyse mit LLMs...
# 5  Der EU AI Act kategorisiert KI-Systeme in vier...
# 6  Christian Winkler beschäftigt sich als Profess...
# 7  The increasing availability of data and data e...
# 8  The provided context does not provide a direct...
# 9  Teilnehmer sollten einen Laptop mitbringen, de...
#
#                                             contexts
# 0  [Wieviel KI müssen wir unseren Kunden erklären...
# 1  [Eine Einführung in Large Language Models\n\nC...
# 2  [KI Power-Play: Realistisches Erwartungsmanage...
# 3  [Die Engineering-Perspektive auf den EU AI Act...
# 4  [Datenanalyse mit Machine Learning\n\nIn diese...
# 5  [Die Engineering-Perspektive auf den EU AI Act...
# 6  [Schluss mit Prototyp: GPTx und RAG in der Pra...
# 7  [Datenanalysen im Fußball – ein Überblick\n\nS...
# 8  [KI Power-Play: Realistisches Erwartungsmanage...
# 9  [Datenanalyse mit Machine Learning\n\nIn diese...

# %%
# assign span ids to the ragas evaluation scores (needed so Phoenix knows where to attach the spans).
span_questions = (
    spans_dataframe[["input"]]
    .sort_values("input")
    .drop_duplicates(subset=["input"], keep="first")
    .reset_index()
    .rename({"input": "question"}, axis=1)
)

ragas_evals_df = ragas_evals_df.merge(span_questions, on="question").set_index("context.span_id")
eval_data_df = eval_data_df.merge(span_questions, on="question").set_index("context.span_id")
eval_scores_df.index = eval_data_df.index
eval_scores_df

# %%
for eval_name in eval_scores_df.columns:
    evals_df = eval_scores_df[[eval_name]].rename(columns={eval_name: "score"})
    evals = SpanEvaluations(eval_name, evals_df)
    px.Client().log_evaluations(evals)

# %%
px.close_app()
